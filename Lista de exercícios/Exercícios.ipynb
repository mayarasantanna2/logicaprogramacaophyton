# %% [markdown]
# <a href="https://colab.research.google.com/github/mayarasantanna2/logicaprogramacaophyton/blob/main/Lista%20de%20exerc%C3%ADcios/Exerc%C3%ADcios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Comisssão
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#entrada
pu = float(input("Digite o preço unitário de cada peça: "))
qtd = float(input("Digite a quantidade de peças vendida: "))

#processamento
total = (pu*qtd)* 5/100

#saida
print("O total do pagamento + a comissão é de: ",total)
# Out:
# Digite o preço unitário de cada peça: 3
# Digite a quantidade de peças vendida: 250
# O total do pagamento + a comissão é de:  37.5

# %% [markdown]
# #conversão em dolar
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#entrada
cd = float(input("digite a cotação atual do  dolar: "))
v = float(input("digite o valor que deseja converter para dólar: "))

#processamento
vc = v/cd

#saída
print("o valor convertido em dólar é: ",vc)
# Out:
# digite a cotação atual do  dolar: 4.5
# digite o valor que deseja converter para dólar: 100
# o valor convertido em dólar é:  22.22222222222222

# %% [markdown]
# #Custo consumidor
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#entrada

cf = float(input("Escreva o custo de fabrica do carro: "))

#processamento

im = cf/100*45
ti = cf+im
dis = ti/100*28
tdis = dis+ti

pc = tdis

#saida
print("o custo ao consumidor é: ",pc)
# Out:
# Escreva o custo de fabrica do carro: 28000
# o custo ao consumidor é:  51968.0

# %% [markdown]
# #Gasolina

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#entrada
km = float(input("digite os kilometros a percorrer:"))
cg = float(input("digite o consumo de gasoina do carro (por litro):"))
pg = float(input("digite o preço medio da gasolina:"))
#processamento
c= km/cg
g= c*pg
#saida
print("O gasto com gasolina será de: ",g)
# Out:
# digite os kilometros a percorrer:250
# digite o consumo de gasoina do carro (por litro):5
# digite o preço medio da gasolina:4.50
# O gasto com gasolina será de:  225.0

# %% [markdown]
# #Hora extra
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#entrada
h = float(input("digite o tempo de trabalho (horas):"))
mt = float(input("digite o tempo de trabalho (minutos):"))
vh = float(input("digite o salário ganho por hora:"))
#processamento
min = mt/60
horas = h+min

ht = h*vh
pht = ht/100*70
total = pht+ht
#saida
print("você deverá ganhar: ",total)
# Out:
# digite o tempo de trabalho (horas):20
# digite o tempo de trabalho (minutos):0
# digite o salário ganho por hora:25
# você deverá ganhar:  850.0

# %% [markdown]
# #Horas em segundos
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#entrada
hr = float(input("escreva a quantidade de  horas: "))
min = float(input("escreva oa quantidade de  minutos: "))
#processamento
m = min/60
total = hr+m
#saida
print("O total em segundos é: ",total)
# Out:
# escreva a quantidade de  horas: 1
# escreva oa quantidade de  minutos: 13
# O total em segundos é:  1.2166666666666668

# %% [markdown]
# #Média entre duas notas
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#entrada
p1 = float(input("digite a primeira nota, entre 0 a 10: "))
p2 = float(input("digite a segunda nota: "))
# Out:
# digite a primeira nota, entre 0 a 10: 8
# digite a segunda nota: 7.5

# %% [markdown]
# #Quadrado dos números
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#entrada
print("Digite os números a seguir:")
n1 = float(input("1° número: "))
n2 = float(input("2° número: "))
n3 = float(input("3° número: "))
n4 = float(input("4° número: "))

#processamento
N1= n1*n1
N2= n2*n2
N3= n3*n3
N4= n4*n4

total= N1+N2+N3+N4

#saida
print("A soma do quadrado dos números inseridos é: ",total)
# Out:
# Digite os números a seguir:

# %% [markdown]
# #Velocidade média
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#entrada
hr = float(input("escreva o tempo gasto no percurso (horas): "))
min = float(input("escreva o tempo gasto no percurso (minutos): "))
km= float(input("escreva os kilometros percorridos: "))
#processamento
m = min/60
tempo = hr+m
vm= km/tempo
#saida
print("A velocidade média é de: ",vm)
# Out:
# escreva o tempo gasto no percurso (horas): 5
# escreva o tempo gasto no percurso (minutos): 0
# escreva os kilometros percorridos: 430
# A velocidade média é de:  86.0
